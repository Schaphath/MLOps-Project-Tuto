# %%
import pandas as pd 
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\LENOVO\\Desktop\\Docker-Compose-Tuto'

# %%
os.chdir("..")
os.getcwd()
# Out:
# 'c:\\Users\\LENOVO\\Desktop\\Docker-Compose-Tuto'

# %%
df = pd.read_csv("Data/evaluate/cancer_eval.csv")

# %%
df.head(5)
# Out:
#   diagnosis  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0         M       27.0300          21.28           133.10      1911.5
# 1         B        9.8339          16.83            71.10       485.0
# 2         B       13.5000          22.06            63.75       238.2
# 3         M       18.4700          23.27           138.20      2132.6
# 4         B       10.6200          18.60            79.23       399.4
#
#    smoothness_worst  compactness_worst  concavity_worst  concave_points_worst  \
# 0            0.1229             0.2326           0.4808                0.1712
# 1            0.1294             0.2480           0.1028                0.0604
# 2            0.1368             0.2409           0.2389                0.0949
# 3            0.1765             0.3863           0.3261                0.1461
# 4            0.1435             0.1530           0.1174                0.1161
#
#    symmetry_worst  fractal_dimension_worst
# ...

# %%
df.describe()
# Out:
#        radius_worst  texture_worst  perimeter_worst  area_worst  \
# count    100.000000     100.000000       100.000000   100.00000
# mean      16.231420      20.259400       108.989100   927.74100
# std        5.578287       3.332993        34.574831   546.84728
# min        7.000000      13.910000        50.000000   200.00000
# 25%       11.452500      17.855000        79.015000   463.45000
# 50%       15.035000      20.015000       101.100000   722.30000
# 75%       21.110000      22.895000       138.800000  1469.00000
# max       28.500000      27.730000       178.300000  2132.60000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        100.000000         100.000000       100.000000
# mean           0.137690           0.260795         0.277961
# std            0.018706           0.112449         0.156432
# min            0.090000           0.070000         0.020000
# 25%            0.123650           0.182175         0.137650
# ...
